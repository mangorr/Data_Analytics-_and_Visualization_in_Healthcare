# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("diabetes.csv")

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Patient_ID              520 non-null    int64
#  1   Treatment               520 non-null    bool
#  2   HemoglobinA1C.Baseline  520 non-null    float64
#  3   HemoglobinA1C.Followup  520 non-null    float64
#  4   Female                  520 non-null    bool
#  5   Age                     520 non-null    int64
#  6   SBP                     520 non-null    int64
#  7   BMI                     520 non-null    float64
# dtypes: bool(2), float64(3), int64(3)
# memory usage: 25.5 KB

# %% [markdown]
# # 1. Show the first 15 rows of the dataset.

# %%
data.head(15)
# Out:
#     Patient_ID  Treatment  HemoglobinA1C.Baseline  HemoglobinA1C.Followup  \
# 0            1      False                     4.9                     7.1
# 1            2       True                     5.1                     5.4
# 2            3       True                     5.1                     4.3
# 3            4       True                     5.2                     5.1
# 4            5       True                     5.2                     7.1
# 5            6      False                     5.2                     5.0
# 6            7       True                     5.2                     3.1
# 7            8       True                     5.4                     5.8
# 8            9       True                     5.5                     6.1
# 9           10       True                     5.6                     3.7
# 10          11      False                     5.6                     5.7
# 11          12       True                     5.6                     6.5
# ...

# %% [markdown]
# # 2. Show rows 15 to 25 with the column “BMI”.

# %%
data.loc[14:24,['BMI']]
# Out:
#       BMI
# 14  25.53
# 15  31.78
# 16  32.61
# 17  28.26
# 18  29.75
# 19  26.67
# 20  30.29
# 21  31.88
# 22  32.60
# 23  26.74
# 24  29.34

# %% [markdown]
# # 3. Show rows 25 through 50 with the columns "Age" and "BMI”.

# %%
data.loc[24:49,['Age', 'BMI']]
# Out:
#     Age    BMI
# 24   54  29.34
# 25   51  25.68
# 26   67  28.91
# 27   32  33.37
# 28   49  29.42
# 29   59  29.95
# 30   36  30.53
# 31   56  28.68
# 32   48  29.26
# 33   48  28.41
# 34   35  30.53
# 35   66  28.64
# 36   47  28.63
# 37   38  29.59
# 38   65  31.99
# 39   54  35.18
# 40   35  26.72
# 41   41  31.30
# 42   41  30.30
# 43   59  30.93
# 44   51  27.08
# 45   43  28.44
# 46   72  29.04
# 47   46  27.81
# 48   57  26.77
# 49   67  27.32

# %% [markdown]
# # 4. Show the systolic blood pressure (SBP) and BMI of female patients that are 65 or older.

# %%
data.loc[(data["Age"] >= 65) & (data["Female"] == True), ['SBP', 'BMI']]
# Out:
#      SBP    BMI
# 26   136  28.91
# 46   131  29.04
# 49   131  27.32
# 53   107  23.02
# 56   158  36.47
# 60   143  31.59
# 73   151  34.49
# 97   124  28.29
# 100  147  29.48
# 109  139  32.34
# 111  148  32.63
# 116  135  27.97
# 127  129  26.38
# 128  125  32.97
# 137  138  37.08
# 162  143  36.68
# 168  150  27.82
# 169  123  29.74
# 174  125  30.25
# 190  155  35.09
# 216  147  35.43
# 217  116  30.42
# 254  153  32.14
# 262  149  36.80
# 293  155  34.58
# 298  128  27.84
# 302  148  30.38
# 306  125  29.92
# 316  121  30.00
# 319  137  32.77
# 327  174  39.63
# 331  124  31.26
# 332  138  32.89
# 339  163  33.32
# 368  131  30.29
# 373  152  36.74
# 391  145  33.31
# 413  139  30.12
# 424  138  34.06
# 434  133  32.39
# 437  122  29.02
# 446  163  37.02
# 462  141  33.47
# 489  149  31.27
# 495  145  36.01
# 518  129  29.31

# %% [markdown]
# # 5. Show the mean and standard deviation of the BMI of obese female patients (BMI 25.0 to <30).

# %%
diabetes = (data[(data["BMI"]>=25.0) & (data["BMI"]<30) & (data["Female"]==True)])["BMI"]

if len(diabetes) > 0:
  diabetes_mean = diabetes.mean()
  diabetes_sd = diabetes.std()
    
print("Mean is : ", diabetes_mean)
print("Standard Deviation is : ", diabetes_sd)
# Out:
# Mean is :  28.525374999999997
# Standard Deviation is :  1.1348595449256536

# %% [markdown]
# # 6. Create histograms for Hemoglobin A1C (baseline and follow-up), SBP, and BMI.

# %%
HemoglobinA1C_Baseline = data['HemoglobinA1C.Baseline']
HemoglobinA1C_Baseline.hist()
plt.show()

# %%
HemoglobinA1C_Followup = data['HemoglobinA1C.Followup']
HemoglobinA1C_Followup.hist()
plt.show()

# %%
SBP = data['SBP']
SBP.hist()
plt.show()

# %%
BMI = data['BMI']
BMI.hist()
plt.show()

# %% [markdown]
# # 7. Show the mean of the BMI of men who are obese (BMI over 30).

# %%
obsedMen = (data[(data["BMI"]>30) & (data["Female"]==False)])["BMI"]

if len(obsedMen) > 0:
  obsedMen_mean = obsedMen.mean()
    
print("Mean is : ", obsedMen_mean)
# Out:
# Mean is :  33.15818652849741

# %% [markdown]
# # 8. Show the total number of patients with normal blood pressure (systolic blood pressure less than 120 mm Hg).

# %%
nomalSBP = (data[(data["SBP"]<120)])["SBP"]
print("nomalSBP number : ", len(nomalSBP))
# Out:
# nomalSBP number :  80

# %% [markdown]
# # 9. Show the percentage of females with high blood pressure (SBP of 130 mm Hg or higher).

# %%
highSBPFemale = len(data[(data["SBP"]>=130) & (data["Female"]==True)])
count = len(data[(data["Female"]==True)])
precentage = highSBPFemale / count

print("Percentage of females with high blood pressur", precentage)
# Out:
# Percentage of females with high blood pressur 0.5150375939849624

# %% [markdown]
# # 10. Build a bar chart of the number of patients by the blood sugar levels (normal, prediabetes, and diabetes) at baseline.

# %% [markdown]
# ## • A normal A1C level is below 5.7%.

# %% [markdown]
# ## • A level of 5.7% to 6.4% indicates prediabetes.

# %% [markdown]
# ## • A level of 6.5% or more indicates diabetes.

# %%
normal = (data[(data["HemoglobinA1C.Baseline"])<5.7])["HemoglobinA1C.Followup"]
pre_diabetes = (data[(data["HemoglobinA1C.Followup"]>=5.7) & (data["HemoglobinA1C.Followup"]<=6.4)])["HemoglobinA1C.Followup"]
diabetes = (data[(data["HemoglobinA1C.Followup"])>=6.5])["HemoglobinA1C.Followup"]

# %%
name_list = ['normal','pre_diabetes','diabetes']
num_list = [len(normal), len(pre_diabetes), len(diabetes)]

plt.title("The number of patients by the blood sugar levels at baseline.")
plt.xlabel("The blood sugar levels")
plt.ylabel("The number of patients")

plt.bar(range(len(num_list)), num_list,tick_label=name_list)
plt.show()
